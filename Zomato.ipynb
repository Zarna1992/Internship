# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df1=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset4/main/zomato.csv",encoding="latin-1")
df1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df2 = pd.read_excel(r'C:\Data Science\Project Phase\Project 6\Country-Code (3).xlsx')
print(df2)
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df=df1.merge(df2)

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
df.shape
# Out:
# (9551, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
#from the above it is being displayed that our dataset is having three kind of data object, float and int64

# %%
#We have to predict two things
#1) Average Cost for two
#2) Price range

#Target variables are "Average Cost for two " and "Price range" and others are features columns.

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
#Null values in Cuisines only

# %%
df.nunique().to_frame('unique values')
# Out:
#                       unique values
# Restaurant ID                  9551
# Restaurant Name                7446
# Country Code                     15
# City                            141
# Address                        8918
# Locality                       1208
# Locality Verbose               1265
# Longitude                      8120
# Latitude                       8677
# Cuisines                       1825
# Average Cost for two            140
# Currency                         12
# Has Table booking                 2
# Has Online delivery               2
# Is delivering now                 2
# Switch to order menu              1
# Price range                       4
# Aggregate rating                 33
# Rating color                      6
# Rating text                       6
# Votes                          1012
# Country                          15

# %%
#filling null values
null_columns =['Cuisines']
for i in null_columns:
    df.fillna(df[i].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
object_datatype=[]
for x in df.dtypes.index:
    if df.dtypes[x]=='O':
        object_datatype.append(x)
print('object = ',object_datatype)        

int_datatype= []
for x in df.dtypes.index:
    if df.dtypes[x]=='int64':
        int_datatype.append(x)
print('integer 64 = ' ,int_datatype)
# Out:
# object =  ['Restaurant Name', 'City', 'Address', 'Locality', 'Locality Verbose', 'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Switch to order menu', 'Rating color', 'Rating text', 'Country']
# integer 64 =  ['Restaurant ID', 'Country Code', 'Average Cost for two', 'Price range', 'Votes']

# %%
df['Restaurant Name'].value_counts()
# Out:
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: Restaurant Name, Length: 7446, dtype: int64

# %%
df["Switch to order menu"].value_counts()
# Out:
# No    9551
# Name: Switch to order menu, dtype: int64

# %%
df.drop(columns=['Restaurant Name','Switch to order menu','Is delivering now'],inplace=True)

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Country Code', 'City', 'Address', 'Locality',
#        'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Price range', 'Aggregate rating',
#        'Rating color', 'Rating text', 'Votes', 'Country'],
#       dtype='object')

# %%
df['Country'].nunique()
# Out:
# 15

# %%
df['Country'].value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
df=df[df['Country Code']==1]
df.shape
# Out:
# (8652, 19)

# %%
df.drop(columns=['Restaurant ID','Country Code','Currency',"Country"],inplace=True)

# %%
df.columns
# Out:
# Index(['City', 'Address', 'Locality', 'Locality Verbose', 'Longitude',
#        'Latitude', 'Cuisines', 'Average Cost for two', 'Has Table booking',
#        'Has Online delivery', 'Price range', 'Aggregate rating',
#        'Rating color', 'Rating text', 'Votes'],
#       dtype='object')

# %%
df['City'].nunique()
# Out:
# 43

# %%
df['City'].value_counts()
# Out:
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Ahmedabad         21
# Guwahati          21
# Lucknow           21
# Bhubaneshwar      21
# Amritsar          21
# Pune              20
# Puducherry        20
# Patna             20
# Ludhiana          20
# Ranchi            20
# Surat             20
# Vadodara          20
# Nashik            20
# Nagpur            20
# Mysore            20
# Mumbai            20
# Varanasi          20
# Mangalore         20
# Agra              20
# Kochi             20
# Kolkata           20
# Dehradun          20
# Allahabad         20
# Aurangabad        20
# Bangalore         20
# Bhopal            20
# Chennai           20
# Coimbatore        20
# Goa               20
# Indore            20
# Jaipur            20
# Kanpur            20
# Vizag             20
# Chandigarh        18
# Hyderabad         18
# Secunderabad       2
# Panchkula          1
# Mohali             1
# ...

# %%
df=df[df['City'].isin(['New Delhi','Gurgaon','Noida','Faridabad'])]

# %%
df.shape
# Out:
# (7922, 15)

# %%
df.columns
# Out:
# Index(['City', 'Address', 'Locality', 'Locality Verbose', 'Longitude',
#        'Latitude', 'Cuisines', 'Average Cost for two', 'Has Table booking',
#        'Has Online delivery', 'Price range', 'Aggregate rating',
#        'Rating color', 'Rating text', 'Votes'],
#       dtype='object')

# %%
df['Cuisines'].value_counts()
# Out:
# North Indian                                      901
# North Indian, Chinese                             474
# Fast Food                                         330
# Chinese                                           323
# North Indian, Mughlai                             313
#                                                  ...
# North Indian, Indian                                1
# Afghani, Mughlai, Chinese                           1
# Awadhi, Mughlai, North Indian                       1
# Chinese, Lucknowi                                   1
# Chinese, North Indian, South Indian, Fast Food      1
# Name: Cuisines, Length: 1156, dtype: int64

# %%
avgprice=df.groupby('Cuisines').mean()['Average Cost for two'].sort_values(ascending=False).reset_index()

# %%
df=df.merge(avgprice, on='Cuisines')
df
# Out:
#            City                                            Address  \
# 0     Faridabad  G 25/22, Main Road, 40 Feet, Molarband Extensi...
# 1     New Delhi  Shop 3, Plot 1161, Opposite Old Sabji Mandi, K...
# 2     Faridabad  11/6, Delhi Mathura Road, Near Bharat Petrol P...
# 3     Faridabad  158/7, Opposite DDA Flat, Pul Pehlad Pur, Char...
# 4     Faridabad  Hotel Saffron Kiran, 12/6, Adjacent to Badarpu...
# ...         ...                                                ...
# 7917      Noida  205-A, 1st Floor, Spice World Mall, Sector 25-...
# 7918      Noida  101, Food Court, Supertech Shopprix Mall, Sect...
# 7919      Noida  63-C, 134-B, Supertech Shopprix Mall, Sector 6...
# 7920      Noida  320-A, 3rd Floor, The Great India Place Mall, ...
# 7921      Noida  A-2, 3rd Floor, The Great India Place Mall, Se...
#
#                                 Locality  \
# 0                        Badarpur Border
# 1                                 Narela
# ...

# %%
df.rename(columns={'Average Cost for two_y':'Cuisine','Average Cost for two_x':'target'},inplace=True)
df
# Out:
#            City                                            Address  \
# 0     Faridabad  G 25/22, Main Road, 40 Feet, Molarband Extensi...
# 1     New Delhi  Shop 3, Plot 1161, Opposite Old Sabji Mandi, K...
# 2     Faridabad  11/6, Delhi Mathura Road, Near Bharat Petrol P...
# 3     Faridabad  158/7, Opposite DDA Flat, Pul Pehlad Pur, Char...
# 4     Faridabad  Hotel Saffron Kiran, 12/6, Adjacent to Badarpu...
# ...         ...                                                ...
# 7917      Noida  205-A, 1st Floor, Spice World Mall, Sector 25-...
# 7918      Noida  101, Food Court, Supertech Shopprix Mall, Sect...
# 7919      Noida  63-C, 134-B, Supertech Shopprix Mall, Sector 6...
# 7920      Noida  320-A, 3rd Floor, The Great India Place Mall, ...
# 7921      Noida  A-2, 3rd Floor, The Great India Place Mall, Se...
#
#                                 Locality  \
# 0                        Badarpur Border
# 1                                 Narela
# ...

# %%
df.drop(columns=['Address','Locality','Locality Verbose','Cuisines'],inplace=True)

# %%
df.columns
# Out:
# Index(['City', 'Longitude', 'Latitude', 'target', 'Has Table booking',
#        'Has Online delivery', 'Price range', 'Aggregate rating',
#        'Rating color', 'Rating text', 'Votes', 'Cuisine'],
#       dtype='object')

# %%
df['Has Table booking'].value_counts()
# Out:
# No     6876
# Yes    1046
# Name: Has Table booking, dtype: int64

# %%
df['Has Table booking'].replace('No',0,inplace=True) #used to replace string value with numerical one
df['Has Table booking'].replace('Yes',1,inplace=True)

# %%
df['Has Table booking'].value_counts()
# Out:
# 0    6876
# 1    1046
# Name: Has Table booking, dtype: int64

# %%
df['Has Online delivery'].value_counts()
# Out:
# No     5609
# Yes    2313
# Name: Has Online delivery, dtype: int64

# %%
df['Has Online delivery'].replace('No',0,inplace=True) #used to replace string value with numerical one
df['Has Online delivery'].replace('Yes',1,inplace=True)

# %%
df['Has Online delivery'].value_counts()
# Out:
# 0    5609
# 1    2313
# Name: Has Online delivery, dtype: int64

# %%
df.columns
# Out:
# Index(['City', 'Longitude', 'Latitude', 'target', 'Has Table booking',
#        'Has Online delivery', 'Price range', 'Aggregate rating',
#        'Rating color', 'Rating text', 'Votes', 'Cuisine'],
#       dtype='object')

# %%
df['Price range'].value_counts()
# Out:
# 1    4221
# 2    2583
# 3     814
# 4     304
# Name: Price range, dtype: int64

# %%
df['Rating color'].value_counts()
# Out:
# Orange        3571
# White         2137
# Yellow        1580
# Green          413
# Red            178
# Dark Green      43
# Name: Rating color, dtype: int64

# %%
df.corr()
# Out:
#                      Longitude  Latitude    target  Has Table booking  \
# Longitude             1.000000  0.997829  0.071752           0.059417
# Latitude              0.997829  1.000000  0.070993           0.059974
# target                0.071752  0.070993  1.000000           0.642966
# Has Table booking     0.059417  0.059974  0.642966           1.000000
# Has Online delivery   0.138671  0.138488  0.076953           0.074300
# Price range           0.083845  0.083131  0.847985           0.658627
# Aggregate rating      0.224523  0.224383  0.328440           0.248363
# Votes                 0.071641  0.071598  0.299089           0.223811
# Cuisine               0.048805  0.048014  0.808274           0.563860
#
#                      Has Online delivery  Price range  Aggregate rating  \
# Longitude                       0.138671     0.083845          0.224523
# Latitude                        0.138488     0.083131          0.224383
# ...

# %%
df.corr()['target']
# Out:
# Longitude              0.071752
# Latitude               0.070993
# target                 1.000000
# Has Table booking      0.642966
# Has Online delivery    0.076953
# Price range            0.847985
# Aggregate rating       0.328440
# Votes                  0.299089
# Cuisine                0.808274
# Name: target, dtype: float64

# %%
df.drop(columns=['Rating color','Has Online delivery'],inplace=True)

# %%
df.columns
# Out:
# Index(['City', 'Longitude', 'Latitude', 'target', 'Has Table booking',
#        'Price range', 'Aggregate rating', 'Rating text', 'Votes', 'Cuisine'],
#       dtype='object')

# %%
y=df['target'].values

# %%
y
# Out:
# array([ 250,  500,  500, ...,  450, 1000,  450], dtype=int64)

# %%
input1=df.drop(columns=['target'])

# %%
X=input1.iloc[:,:].values

# %%
X
# Out:
# array([['Faridabad', 77.3066401, 28.4900591, ..., 'Average', 4, 375.0],
#        ['New Delhi', 77.04952508, 28.80619877, ..., 'Not rated', 0,
#         375.0],
#        ['Faridabad', 77.304776, 28.4901567, ..., 'Average', 16,
#         594.3037974683544],
#        ...,
#        ['Noida', 77.3648332, 28.5971027, ..., 'Good', 105, 450.0],
#        ['Noida', 77.32321292, 28.5677509, ..., 'Not rated', 0, 1000.0],
#        ['Noida', 77.3253081, 28.5671503, ..., 'Poor', 161, 450.0]],
#       dtype=object)

# %%
X.shape
# Out:
# (7922, 9)

# %%
y.shape
# Out:
# (7922,)

# %%
X
# Out:
# array([['Faridabad', 77.3066401, 28.4900591, ..., 'Average', 4, 375.0],
#        ['New Delhi', 77.04952508, 28.80619877, ..., 'Not rated', 0,
#         375.0],
#        ['Faridabad', 77.304776, 28.4901567, ..., 'Average', 16,
#         594.3037974683544],
#        ...,
#        ['Noida', 77.3648332, 28.5971027, ..., 'Good', 105, 450.0],
#        ['Noida', 77.32321292, 28.5677509, ..., 'Not rated', 0, 1000.0],
#        ['Noida', 77.3253081, 28.5671503, ..., 'Poor', 161, 450.0]],
#       dtype=object)

# %%
#convert categorical string to numerical label 
#one hot encoding 9-1=8,8+4(categorical)=12

# %%
X[:,0]=encoder.fit_transform(X[:,0])
X[:,-3]=encoder.fit_transform(X[:,-3])

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
oencoder=OneHotEncoder(categorical_features=[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9112\4191871496.py in <module>
# ----> 1 oencoder=OneHotEncoder(categorical_features=[0])
#
# TypeError: __init__() got an unexpected keyword argument 'categorical_features'

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
